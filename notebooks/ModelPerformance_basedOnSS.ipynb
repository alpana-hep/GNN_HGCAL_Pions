# %%
#import the stuff
import pandas as pd #dataframes etc
import matplotlib.pyplot as plt #plotting
import pickle
import numpy as np
import os, sys
import seaborn as sns
#import the stuff
import pandas as pd #dataframes etc
import matplotlib.pyplot as plt #plotting
import pickle
import numpy as np
import os, sys
import seaborn as sns

# %%
import awkward
import pickle
import numpy as np
pred_v2 ="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/pred_tb.pickle"
predPickle = open(pred_v2, "rb")
print(predPickle)
preds_trueEn = np.asarray(pickle.load(predPickle))
#print(preds[0])
trueEn= "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/trueE.pickle"
trueEnPickle = open(trueEn,"rb")
trueEn_pkl = np.asarray(pickle.load(trueEnPickle))
valid_idx_file="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/all_valididx.pickle"
train_idx_file="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/all_trainidx.pickle"

valid_idx_f = open(valid_idx_file,"rb")
valid_idx = np.asarray(pickle.load(valid_idx_f))
print(len(valid_idx))

train_idx_f = open(train_idx_file,"rb")
train_idx = np.asarray(pickle.load(train_idx_f))
print(len(train_idx))
## reading tb data files
tb_valid_idx_file="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/TB_data/all_valididx.pickle"
tb_train_idx_file="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/TB_data/all_trainidx.pickle"
tb_pred_v2 ="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/tb_data/pred_tb.pickle"
tb_predPickle = open(tb_pred_v2, "rb")
print(tb_predPickle)
tb_preds_trueEn = np.asarray(pickle.load(tb_predPickle))

tb_trueEn= "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/TB_data/trueE.pickle"
tb_trueEnPickle = open(tb_trueEn,"rb")
tb_trueEn_pkl = np.asarray(pickle.load(tb_trueEnPickle))
print(tb_trueEn_pkl[200000])



## reading shower start location eventwise
SSLocation_file_sim = "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/SsLocation.pickle"
SSLocation_sim =  open(SSLocation_file_sim,"rb")
SSLocation_arr_sim = np.asarray(pickle.load(SSLocation_sim))
print(SSLocation_arr_sim[0])
SSLocation_file_data = "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/TB_data/SsLocation.pickle"
SSLocation_data =  open(SSLocation_file_data,"rb")
SSLocation_arr_data = np.asarray(pickle.load(SSLocation_data))
print(SSLocation_arr_data[0])


SSLocation_file_QGSP = "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/ScalingMC_RechitLevel/52_Onwards/QGSP/SsLocation.pickle"
SSLocation_QGSP =  open(SSLocation_file_QGSP,"rb")
SSLocation_arr_QGSP = np.asarray(pickle.load(SSLocation_QGSP))
print(SSLocation_arr_QGSP[0])

SSLocation_file_FTFP = "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/ScalingMC_RechitLevel/52_Onwards/FTFP/SsLocation.pickle"
SSLocation_FTFP =  open(SSLocation_file_FTFP,"rb")
SSLocation_arr_FTFP = np.asarray(pickle.load(SSLocation_FTFP))
print(SSLocation_arr_FTFP[0])
# Out:
# <_io.BufferedReader name='/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/pred_tb.pickle'>
# 167332
# 669326
# <_io.BufferedReader name='/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/tb_data/pred_tb.pickle'>
# 80.0
# 31
# 32
# 29
# 7

# %%
trueEn_Valid_MipsInEE=[]
PredEn_Valid_MipsInEE=[]
trueEn_Valid_SSinEE=[]
PredEn_Valid_SSinEE=[]
trueEn_Train_MipsInEE=[]
PredEn_Train_MipsInEE=[]
trueEn_Train_SSinEE=[]
PredEn_Train_SSinEE=[]


for i in range(len(valid_idx)):
    valid_trueEn=(trueEn_pkl[valid_idx[i]])
    valid_predEn=(preds_trueEn[valid_idx[i]])
    SS_location= SSLocation_arr_sim[valid_idx[i]]
    if(SS_location<=28):
        trueEn_Valid_SSinEE.append(valid_trueEn)
        PredEn_Valid_SSinEE.append(valid_predEn)
    elif(SS_location>28):
        trueEn_Valid_MipsInEE.append(valid_trueEn)
        PredEn_Valid_MipsInEE.append(valid_predEn)
    else:
        continue
for i in range(len(train_idx)):
    train_trueEn=(trueEn_pkl[train_idx[i]])
    train_predEn=(preds_trueEn[train_idx[i]])
    SS_location= SSLocation_arr_sim[train_idx[i]]
    if(SS_location<=28):
        
        trueEn_Train_SSinEE.append(train_trueEn)
        PredEn_Train_SSinEE.append(train_predEn)
    elif(SS_location>28):
        trueEn_Train_MipsInEE.append(train_trueEn)
        PredEn_Train_MipsInEE.append(train_predEn)
    else:
        continue

# %%
trueEn_TB_MipsInEE=[]
PredEn_TB_MipsInEE=[]
trueEn_TB_SSinEE=[]
PredEn_TB_SSinEE=[]
for i in range(len(tb_preds_trueEn)):
    valid_trueEn=(tb_trueEn_pkl[i])
    valid_predEn=(tb_preds_trueEn[i])
    SS_location= SSLocation_arr_data[i]
    if(SS_location<=28):
        trueEn_TB_SSinEE.append(valid_trueEn)
        PredEn_TB_SSinEE.append(valid_predEn)
    elif(SS_location>28):
        trueEn_TB_MipsInEE.append(valid_trueEn)
        PredEn_TB_MipsInEE.append(valid_predEn)
    else:
        continue

# %%
QGSP_pred_v2 ="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/QGSP/pred_tb.pickle"
QGSP_predPickle = open(QGSP_pred_v2, "rb")
print(QGSP_predPickle)
QGSP_preds_trueEn = np.asarray(pickle.load(QGSP_predPickle))

QGSP_trueEn= "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/ScalingMC_RechitLevel/QGSP_tb_/beamEn.pickle"
QGSP_trueEnPickle = open(QGSP_trueEn,"rb")
QGSP_trueEn_pkl = np.asarray(pickle.load(QGSP_trueEnPickle))
# Out:
# <_io.BufferedReader name='/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/QGSP/pred_tb.pickle'>

# %%
trueEn_QGSP_MipsInEE=[]
PredEn_QGSP_MipsInEE=[]
trueEn_QGSP_SSinEE=[]
PredEn_QGSP_SSinEE=[]
for i in range(len(QGSP_preds_trueEn)):
    valid_trueEn=(QGSP_trueEn_pkl[i])
    valid_predEn=(QGSP_preds_trueEn[i])
    SS_location= SSLocation_arr_QGSP[i]
    if(SS_location<=28):
        trueEn_QGSP_SSinEE.append(valid_trueEn)
        PredEn_QGSP_SSinEE.append(valid_predEn)
    elif(SS_location>28):
        trueEn_QGSP_MipsInEE.append(valid_trueEn)
        PredEn_QGSP_MipsInEE.append(valid_predEn)
    else:
        continue

# %%
FTFP_pred_v2 ="/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/FTFP/pred_tb.pickle"
FTFP_predPickle = open(FTFP_pred_v2, "rb")
print(FTFP_predPickle)
FTFP_preds_trueEn = np.asarray(pickle.load(FTFP_predPickle))

FTFP_trueEn= "/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/ScalingMC_RechitLevel/FTFP_tb_/beamEn.pickle"
FTFP_trueEnPickle = open(FTFP_trueEn,"rb")
FTFP_trueEn_pkl = np.asarray(pickle.load(FTFP_trueEnPickle))
print(FTFP_trueEn_pkl[200000])
# Out:
# <_io.BufferedReader name='/eos/user/k/kalpana/SWAN_projects/GNN_Results/FlatEnegrySample_1M/Nosemi/52_Onwards/FTFP/pred_tb.pickle'>
# 200.0

# %%
trueEn_FTFP_MipsInEE=[]
PredEn_FTFP_MipsInEE=[]
trueEn_FTFP_SSinEE=[]
PredEn_FTFP_SSinEE=[]
for i in range(len(FTFP_preds_trueEn)):
    valid_trueEn=(FTFP_trueEn_pkl[i])
    valid_predEn=(FTFP_preds_trueEn[i])
    SS_location= SSLocation_arr_FTFP[i]
    if(SS_location<=28):
        trueEn_FTFP_SSinEE.append(valid_trueEn)
        PredEn_FTFP_SSinEE.append(valid_predEn)
    elif(SS_location>28):
        trueEn_FTFP_MipsInEE.append(valid_trueEn)
        PredEn_FTFP_MipsInEE.append(valid_predEn)
    else:
        continue

# %%
import ROOT
hist_pred_Valid_SSinEE=[]
hist_true_Valid_SSinEE=[]
hist_pred_Train_SSinEE=[]
hist_true_Train_SSinEE=[]
hist_predTrue_Valid_SSinEE=[]
hist_norm_predTrue_Valid_SSinEE=[]
hist_predTrue_Train_SSinEE=[]
hist_norm_predTrue_Train_SSinEE=[]
hist_pred_Tbdata_SSinEE=[]
hist_true_Tbdata_SSinEE=[]
hist_predTrue_Tbdata_SSinEE=[]
hist_norm_predTrue_Tbdata_SSinEE=[]

hist_pred_QGSP_SSinEE=[]
hist_true_QGSP_SSinEE=[]
hist_pred_FTFP_SSinEE=[]
hist_true_FTFP_SSinEE=[]
hist_predTrue_QGSP_SSinEE=[]
hist_norm_predTrue_QGSP_SSinEE=[]
hist_predTrue_FTFP_SSinEE=[]
hist_norm_predTrue_FTFP_SSinEE=[]
Energy=[20,50,80,100,120,200,250,300]
M=8 # number of histograms
for i_hist in range(M):
    xhigh_pred= 3.0*Energy[i_hist]
    xhigh_true= 2.0*Energy[i_hist]
    xhigh_diff= 20
    xlow_diff= -20
    xhigh_norm= 5
    xlow_norm= -5
    name1='TrueEn_%i' %(Energy[i_hist])#,u[i_hist],v[i_hist],typee[i_hist])
    hist_pred_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_pred_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0,xhigh_pred ))
    hist_true_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
# Out:
# Welcome to JupyROOT 6.24/00

# %%
import ROOT
hist_pred_Valid_SSinEE=[]
hist_true_Valid_SSinEE=[]
hist_pred_Train_SSinEE=[]
hist_true_Train_SSinEE=[]
hist_predTrue_Valid_SSinEE=[]
hist_norm_predTrue_Valid_SSinEE=[]
hist_predTrue_Train_SSinEE=[]
hist_norm_predTrue_Train_SSinEE=[]
hist_pred_Tbdata_SSinEE=[]
hist_true_Tbdata_SSinEE=[]
hist_predTrue_Tbdata_SSinEE=[]
hist_norm_predTrue_Tbdata_SSinEE=[]

hist_pred_QGSP_SSinEE=[]
hist_true_QGSP_SSinEE=[]
hist_pred_FTFP_SSinEE=[]
hist_true_FTFP_SSinEE=[]
hist_predTrue_QGSP_SSinEE=[]
hist_norm_predTrue_QGSP_SSinEE=[]
hist_predTrue_FTFP_SSinEE=[]
hist_norm_predTrue_FTFP_SSinEE=[]
Energy=[20,50,80,100,120,200,250,300]
M=8 # number of histograms
for i_hist in range(M):
    xhigh_pred= 3.0*Energy[i_hist]
    xhigh_true= 2.0*Energy[i_hist]
    xhigh_diff= 20
    xlow_diff= -20
    xhigh_norm= 5
    xlow_norm= -5
    name1='TrueEn_%i' %(Energy[i_hist])#,u[i_hist],v[i_hist],typee[i_hist])
    hist_pred_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Valid_SSinEE.append(ROOT.TH1F('SSinEE_Valid_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Train_SSinEE.append(ROOT.TH1F('SSinEE_Train_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_pred_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0,xhigh_pred ))
    hist_true_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Tbdata_SSinEE.append(ROOT.TH1F('SSinEE_Tbdata_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500,xlow_norm, xhigh_norm ))
    hist_pred_QGSP_SSinEE.append(ROOT.TH1F('SSinEE_QGSP_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_QGSP_SSinEE.append(ROOT.TH1F('SSinEE_QGSP_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_FTFP_SSinEE.append(ROOT.TH1F('SSinEE_FTFP_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_FTFP_SSinEE.append(ROOT.TH1F('SSinEE_FTFP_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_QGSP_SSinEE.append(ROOT.TH1F('SSinEE_QGSP_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_QGSP_SSinEE.append(ROOT.TH1F('SSinEE_QGSP_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_FTFP_SSinEE.append(ROOT.TH1F('SSinEE_FTFP_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_FTFP_SSinEE.append(ROOT.TH1F('SSinEE_FTFP_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    print(i)
# Out:
# 671098
# 671098
# 671098
# 671098
# 671098
# 671098
# 671098
# 671098

# %%
fout= ROOT.TFile("hist_DRn_noSemi_1Mstats_75epochs_withoutscalingMC_EventCateg.root", 'RECREATE')

# %%
hist_pred_Valid_MipsInEE=[]
hist_true_Valid_MipsInEE=[]
hist_pred_Train_MipsInEE=[]
hist_true_Train_MipsInEE=[]
hist_predTrue_Valid_MipsInEE=[]
hist_norm_predTrue_Valid_MipsInEE=[]
hist_predTrue_Train_MipsInEE=[]
hist_norm_predTrue_Train_MipsInEE=[]
hist_pred_Tbdata_MipsInEE=[]
hist_true_Tbdata_MipsInEE=[]
hist_predTrue_Tbdata_MipsInEE=[]
hist_norm_predTrue_Tbdata_MipsInEE=[]

hist_pred_QGSP_MipsInEE=[]
hist_true_QGSP_MipsInEE=[]
hist_pred_FTFP_MipsInEE=[]
hist_true_FTFP_MipsInEE=[]
hist_predTrue_QGSP_MipsInEE=[]
hist_norm_predTrue_QGSP_MipsInEE=[]
hist_predTrue_FTFP_MipsInEE=[]
hist_norm_predTrue_FTFP_MipsInEE=[]
Energy=[20,50,80,100,120,200,250,300]
M=8 # number of histograms
for i_hist in range(M):
    xhigh_pred= 3.0*Energy[i_hist]
    xhigh_true= 2.0*Energy[i_hist]
    xhigh_diff= 20
    xlow_diff= -20
    xhigh_norm= 5
    xlow_norm= -5
    name1='TrueEn_%i' %(Energy[i_hist])#,u[i_hist],v[i_hist],typee[i_hist])
    hist_pred_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_pred_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0,xhigh_pred ))
    hist_true_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500,xlow_norm, xhigh_norm ))

# %%
hist_pred_Valid_MipsInEE=[]
hist_true_Valid_MipsInEE=[]
hist_pred_Train_MipsInEE=[]
hist_true_Train_MipsInEE=[]
hist_predTrue_Valid_MipsInEE=[]
hist_norm_predTrue_Valid_MipsInEE=[]
hist_predTrue_Train_MipsInEE=[]
hist_norm_predTrue_Train_MipsInEE=[]
hist_pred_Tbdata_MipsInEE=[]
hist_true_Tbdata_MipsInEE=[]
hist_predTrue_Tbdata_MipsInEE=[]
hist_norm_predTrue_Tbdata_MipsInEE=[]

hist_pred_QGSP_MipsInEE=[]
hist_true_QGSP_MipsInEE=[]
hist_pred_FTFP_MipsInEE=[]
hist_true_FTFP_MipsInEE=[]
hist_predTrue_QGSP_MipsInEE=[]
hist_norm_predTrue_QGSP_MipsInEE=[]
hist_predTrue_FTFP_MipsInEE=[]
hist_norm_predTrue_FTFP_MipsInEE=[]
Energy=[20,50,80,100,120,200,250,300]
M=8 # number of histograms
for i_hist in range(M):
    xhigh_pred= 3.0*Energy[i_hist]
    xhigh_true= 2.0*Energy[i_hist]
    xhigh_diff= 20
    xlow_diff= -20
    xhigh_norm= 5
    xlow_norm= -5
    name1='TrueEn_%i' %(Energy[i_hist])#,u[i_hist],v[i_hist],typee[i_hist])
    hist_pred_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Valid_MipsInEE.append(ROOT.TH1F('MipsInEE_Valid_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Train_MipsInEE.append(ROOT.TH1F('MipsInEE_Train_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_pred_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0,xhigh_pred ))
    hist_true_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_Tbdata_MipsInEE.append(ROOT.TH1F('MipsInEE_Tbdata_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500,xlow_norm, xhigh_norm ))
    hist_pred_QGSP_MipsInEE.append(ROOT.TH1F('MipsInEE_QGSP_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_QGSP_MipsInEE.append(ROOT.TH1F('MipsInEE_QGSP_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0,xhigh_true ))
    hist_pred_FTFP_MipsInEE.append(ROOT.TH1F('MipsInEE_FTFP_Predi_%s' % name1, """:"Predicted energy in GeV":""", 500, 0, xhigh_pred))
    hist_true_FTFP_MipsInEE.append(ROOT.TH1F('MipsInEE_FTFP_trueEn_%s' % name1, """:"true Beam energy in GeV":""", 500, 0, xhigh_true))
    hist_predTrue_QGSP_MipsInEE.append(ROOT.TH1F('MipsInEE_QGSP_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_QGSP_MipsInEE.append(ROOT.TH1F('MipsInEE_QGSP_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))
    hist_predTrue_FTFP_MipsInEE.append(ROOT.TH1F('MipsInEE_FTFP_Diff_Predi_%s' % name1, """:"Predicted -true in GeV":""", 500, xlow_diff, xhigh_diff))
    hist_norm_predTrue_FTFP_MipsInEE.append(ROOT.TH1F('MipsInEE_FTFP_norm_pred_trueEn_%s' % name1, """:"(pred-true)/true in GeV":""", 500, xlow_norm, xhigh_norm))

# %%
Energy=[20,50,80,100,120,200,250,300]
print(len(trueEn_Valid_MipsInEE))
for i in range(len(trueEn_Valid_MipsInEE)):
    trueEn=(trueEn_Valid_MipsInEE[i])
    predEn=(PredEn_Valid_MipsInEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn>=Energy[ibin]-2 and trueEn<=Energy[ibin]+2 ):
            #print(ibin)
            hist_pred_Valid_MipsInEE[ibin].Fill(predEn)
            hist_true_Valid_MipsInEE[ibin].Fill(trueEn)
            hist_predTrue_Valid_MipsInEE[ibin].Fill(diff)
            hist_norm_predTrue_Valid_MipsInEE[ibin].Fill(norm)
for i in range(len(trueEn_Valid_SSinEE)):
    trueEn=(trueEn_Valid_SSinEE[i])
    predEn=(PredEn_Valid_SSinEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn>=Energy[ibin]-2 and trueEn<=Energy[ibin]+2):
            hist_pred_Valid_SSinEE[ibin].Fill(predEn)
            hist_true_Valid_SSinEE[ibin].Fill(trueEn)
            hist_predTrue_Valid_SSinEE[ibin].Fill(diff)
            hist_norm_predTrue_Valid_SSinEE[ibin].Fill(norm)
for i in range(len(trueEn_Train_MipsInEE)):
    trueEn=(trueEn_Train_MipsInEE[i])
    predEn=(PredEn_Train_MipsInEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn>=Energy[ibin]-2 and trueEn<=Energy[ibin]+2):
            hist_pred_Train_MipsInEE[ibin].Fill(predEn)
            hist_true_Train_MipsInEE[ibin].Fill(trueEn)
            hist_predTrue_Train_MipsInEE[ibin].Fill(diff)
            hist_norm_predTrue_Train_MipsInEE[ibin].Fill(norm)
for i in range(len(trueEn_Train_SSinEE)):
    trueEn=(trueEn_Train_SSinEE[i])
    predEn=(PredEn_Train_SSinEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn>=Energy[ibin]-2 and trueEn<=Energy[ibin]+2):
            hist_pred_Train_SSinEE[ibin].Fill(predEn)
            hist_true_Train_SSinEE[ibin].Fill(trueEn)
            hist_predTrue_Train_SSinEE[ibin].Fill(diff)
            hist_norm_predTrue_Train_SSinEE[ibin].Fill(norm)
# Out:
# 55238

# %%
for i in range(len(trueEn_TB_MipsInEE)):
    trueEn=(trueEn_TB_MipsInEE[i])
    predEn=(PredEn_TB_MipsInEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_Tbdata_MipsInEE[ibin].Fill(predEn)
            hist_true_Tbdata_MipsInEE[ibin].Fill(trueEn)
            hist_predTrue_Tbdata_MipsInEE[ibin].Fill(diff)
            hist_norm_predTrue_Tbdata_MipsInEE[ibin].Fill(norm)
for i in range(len(trueEn_TB_SSinEE)):
    trueEn=(trueEn_TB_SSinEE[i])
    predEn=(PredEn_TB_SSinEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_Tbdata_SSinEE[ibin].Fill(predEn)
            hist_true_Tbdata_SSinEE[ibin].Fill(trueEn)
            hist_predTrue_Tbdata_SSinEE[ibin].Fill(diff)
            hist_norm_predTrue_Tbdata_SSinEE[ibin].Fill(norm)

# %%
for i in range(len(trueEn_FTFP_MipsInEE)):
    trueEn=(trueEn_FTFP_MipsInEE[i])
    predEn=(PredEn_FTFP_MipsInEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_FTFP_MipsInEE[ibin].Fill(predEn)
            hist_true_FTFP_MipsInEE[ibin].Fill(trueEn)
            hist_predTrue_FTFP_MipsInEE[ibin].Fill(diff)
            hist_norm_predTrue_FTFP_MipsInEE[ibin].Fill(norm)
for i in range(len(trueEn_FTFP_SSinEE)):
    trueEn=(trueEn_FTFP_SSinEE[i])
    predEn=(PredEn_FTFP_SSinEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_FTFP_SSinEE[ibin].Fill(predEn)
            hist_true_FTFP_SSinEE[ibin].Fill(trueEn)
            hist_predTrue_FTFP_SSinEE[ibin].Fill(diff)
            hist_norm_predTrue_FTFP_SSinEE[ibin].Fill(norm)

# %%
for i in range(len(trueEn_QGSP_MipsInEE)):
    trueEn=(trueEn_QGSP_MipsInEE[i])
    predEn=(PredEn_QGSP_MipsInEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_QGSP_MipsInEE[ibin].Fill(predEn)
            hist_true_QGSP_MipsInEE[ibin].Fill(trueEn)
            hist_predTrue_QGSP_MipsInEE[ibin].Fill(diff)
            hist_norm_predTrue_QGSP_MipsInEE[ibin].Fill(norm)
for i in range(len(trueEn_QGSP_SSinEE)):
    trueEn=(trueEn_QGSP_SSinEE[i])
    predEn=(PredEn_QGSP_SSinEE[i])
    diff= trueEn - predEn
    norm = diff/trueEn
    for ibin in range(8):
        if(trueEn==Energy[ibin]):
            hist_pred_QGSP_SSinEE[ibin].Fill(predEn)
            hist_true_QGSP_SSinEE[ibin].Fill(trueEn)
            hist_predTrue_QGSP_SSinEE[ibin].Fill(diff)
            hist_norm_predTrue_QGSP_SSinEE[ibin].Fill(norm)

# %%
fout.cd()
for i in range(8):
    hist_pred_Valid_MipsInEE[i].Write()
    hist_true_Valid_MipsInEE[i].Write()
    hist_pred_Train_MipsInEE[i].Write()
    hist_true_Train_MipsInEE[i].Write()
    hist_pred_Tbdata_MipsInEE[i].Write()
    hist_true_Tbdata_MipsInEE[i].Write()
    hist_pred_Valid_SSinEE[i].Write()
    hist_true_Valid_SSinEE[i].Write()
    hist_pred_Train_SSinEE[i].Write()
    hist_true_Train_SSinEE[i].Write()
    hist_pred_Tbdata_SSinEE[i].Write()
    hist_true_Tbdata_SSinEE[i].Write()
    hist_pred_QGSP_SSinEE[i].Write()
    hist_true_QGSP_SSinEE[i].Write()
    hist_pred_QGSP_MipsInEE[i].Write()
    hist_true_QGSP_MipsInEE[i].Write()
    hist_pred_FTFP_SSinEE[i].Write()
    hist_true_FTFP_SSinEE[i].Write()
    hist_pred_FTFP_MipsInEE[i].Write()
    hist_true_FTFP_MipsInEE[i].Write()

fout.Close()
